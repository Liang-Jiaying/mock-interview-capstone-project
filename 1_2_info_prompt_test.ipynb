# %% [markdown]
# # To Do
#
# 1. try few show exaple to let LLMs review resume as my example.
#
# 2. langchain.prompts.example_selector
# https://python.langchain.com/docs/modules/model_io/prompts/example_selectors
#
# 3.

# %%
chain = LLMChain(llm = llm, prompt = prompt)

# %%
chain.run("colorful socks")

# %%
input_list = [
    {"product": "socks"},
    {"product": "computer"},
    {"product": "shoes"}
]

chain.apply(input_list)
